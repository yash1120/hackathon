# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt
import os
import glob
# %matplotlib inline

# %%
IMG_SHAPE = 128
BATCH_SIZE = 64
EPOCHS = 50

# %%
def load_dataset():
    X = []
    y = []
    for path in glob.glob('data/NT/normaltrucks/*.jpg'):
        img = tf.keras.preprocessing.image.load_img(path)
        img = tf.keras.preprocessing.image.smart_resize(tf.keras.preprocessing.image.img_to_array(img)/255.0,(IMG_SHAPE,IMG_SHAPE))
        X.append(img)
        y.append([0])
    for path in glob.glob('data/OT/overtrucks/*.jpg'):
        img = tf.keras.preprocessing.image.load_img(path)
        img = tf.keras.preprocessing.image.smart_resize(tf.keras.preprocessing.image.img_to_array(img)/255.0,(IMG_SHAPE,IMG_SHAPE))
        X.append(img)
        y.append([1])
    X = np.asarray(X)
    y = np.asarray(y)
    return X,y

# %%
X, y = load_dataset()
X.shape, y.shape
# Out:
# ((147, 128, 128, 3), (147, 1))

# %%
plt.imshow(X[5])
plt.title(y[5][0])
plt.show()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True)
X_train.shape, y_train.shape
# Out:
# ((102, 128, 128, 3), (102, 1))

# %%
model = tf.keras.models.Sequential([
    tf.keras.layers.Input((IMG_SHAPE,IMG_SHAPE,3)),
    tf.keras.applications.MobileNet(include_top=False, weights='imagenet'),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(64, activation=tf.keras.layers.LeakyReLU(0.01)),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(loss='binary_crossentropy', optimizer=tf.keras.optimizers.Adam(1e-4), metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not in [128, 160, 192, 224]. Weights for input shape (224, 224) will be loaded as the default.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/mobilenet/mobilenet_1_0_224_tf_no_top.h5
# 17227776/17225924 [==============================] - 4s 0us/step
# 17235968/17225924 [==============================] - 4s 0us/step
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  mobilenet_1.00_224 (Functio  (None, None, None, 1024)  3228864
#  nal)
#
#  flatten (Flatten)           (None, 16384)             0
#
#  dense (Dense)               (None, 64)                1048640
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 4,277,569
# Trainable params: 4,255,681
# Non-trainable params: 21,888
# _________________________________________________________________

# %%
hist = model.fit(X_train, y_train, epochs=EPOCHS, batch_size=BATCH_SIZE,
                 validation_split=0.2, validation_batch_size=8, shuffle=True)
# Out:
# Epoch 1/50
# 2/2 [==============================] - 10s 1s/step - loss: 0.8088 - accuracy: 0.6173 - val_loss: 2.0429 - val_accuracy: 0.5238
# Epoch 2/50
# 2/2 [==============================] - 4s 918ms/step - loss: 0.0751 - accuracy: 0.9630 - val_loss: 2.3293 - val_accuracy: 0.5238
# Epoch 3/50
# 2/2 [==============================] - 4s 1s/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 2.1308 - val_accuracy: 0.5238
# Epoch 4/50
# 2/2 [==============================] - 4s 977ms/step - loss: 6.0841e-04 - accuracy: 1.0000 - val_loss: 1.8667 - val_accuracy: 0.5714
# Epoch 5/50
# 2/2 [==============================] - 4s 901ms/step - loss: 3.4081e-04 - accuracy: 1.0000 - val_loss: 1.6273 - val_accuracy: 0.5714
# Epoch 6/50
# 2/2 [==============================] - 3s 929ms/step - loss: 3.2274e-05 - accuracy: 1.0000 - val_loss: 1.3862 - val_accuracy: 0.6190
# Epoch 7/50
# 2/2 [==============================] - 4s 871ms/step - loss: 1.0408e-05 - accuracy: 1.0000 - val_loss: 1.2017 - val_accuracy: 0.7143
# Epoch 8/50
# 2/2 [==============================] - 4s 947ms/step - loss: 5.9728e-06 - accuracy: 1.0000 - val_loss: 1.0624 - val_accuracy: 0.8095
# Epoch 9/50
# 2/2 [==============================] - 4s 1s/step - loss: 4.2218e-06 - accuracy: 1.0000 - val_loss: 0.9576 - val_accuracy: 0.8095
# Epoch 10/50
# 2/2 [==============================] - 4s 1s/step - loss: 1.9837e-04 - accuracy: 1.0000 - val_loss: 0.8960 - val_accuracy: 0.8571
# Epoch 11/50
# 2/2 [==============================] - 4s 1s/step - loss: 1.0135e-05 - accuracy: 1.0000 - val_loss: 0.8208 - val_accuracy: 0.8571
# Epoch 12/50
# 2/2 [==============================] - 5s 1s/step - loss: 4.4611e-06 - accuracy: 1.0000 - val_loss: 0.7641 - val_accuracy: 0.8571
# Epoch 13/50
# 2/2 [==============================] - 4s 1s/step - loss: 1.9917e-05 - accuracy: 1.0000 - val_loss: 0.7136 - val_accuracy: 0.8571
# Epoch 14/50
# 2/2 [==============================] - 5s 1s/step - loss: 5.7087e-06 - accuracy: 1.0000 - val_loss: 0.6692 - val_accuracy: 0.8571
# Epoch 15/50
# 2/2 [==============================] - 4s 962ms/step - loss: 3.5147e-06 - accuracy: 1.0000 - val_loss: 0.6203 - val_accuracy: 0.8571
# Epoch 16/50
# 2/2 [==============================] - 4s 980ms/step - loss: 3.7463e-06 - accuracy: 1.0000 - val_loss: 0.5755 - val_accuracy: 0.9048
# Epoch 17/50
# 2/2 [==============================] - 4s 913ms/step - loss: 1.7388e-05 - accuracy: 1.0000 - val_loss: 0.5388 - val_accuracy: 0.9048
# Epoch 18/50
# 2/2 [==============================] - 3s 922ms/step - loss: 3.8307e-06 - accuracy: 1.0000 - val_loss: 0.4968 - val_accuracy: 0.9048
# Epoch 19/50
# 2/2 [==============================] - 3s 921ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.4808 - val_accuracy: 0.9048
# Epoch 20/50
# 2/2 [==============================] - 3s 877ms/step - loss: 7.9618e-06 - accuracy: 1.0000 - val_loss: 0.5059 - val_accuracy: 0.8571
# Epoch 21/50
# 2/2 [==============================] - 3s 894ms/step - loss: 2.3855e-04 - accuracy: 1.0000 - val_loss: 0.5186 - val_accuracy: 0.8571
# Epoch 22/50
# 2/2 [==============================] - 5s 1s/step - loss: 1.3027e-05 - accuracy: 1.0000 - val_loss: 0.5280 - val_accuracy: 0.8571
# Epoch 23/50
# 2/2 [==============================] - 5s 1s/step - loss: 8.2417e-06 - accuracy: 1.0000 - val_loss: 0.5349 - val_accuracy: 0.8571
# Epoch 24/50
# 2/2 [==============================] - 4s 835ms/step - loss: 8.6011e-07 - accuracy: 1.0000 - val_loss: 0.5374 - val_accuracy: 0.8571
# Epoch 25/50
# 2/2 [==============================] - 3s 855ms/step - loss: 3.4738e-06 - accuracy: 1.0000 - val_loss: 0.5405 - val_accuracy: 0.8571
# Epoch 26/50
# 2/2 [==============================] - 3s 830ms/step - loss: 4.7399e-07 - accuracy: 1.0000 - val_loss: 0.5339 - val_accuracy: 0.8571
# Epoch 27/50
# 2/2 [==============================] - 3s 987ms/step - loss: 7.2308e-07 - accuracy: 1.0000 - val_loss: 0.5250 - val_accuracy: 0.8571
# Epoch 28/50
# 2/2 [==============================] - 4s 1s/step - loss: 3.2141e-07 - accuracy: 1.0000 - val_loss: 0.5116 - val_accuracy: 0.8571
# Epoch 29/50
# 2/2 [==============================] - 5s 1s/step - loss: 5.0994e-06 - accuracy: 1.0000 - val_loss: 0.4980 - val_accuracy: 0.8571
# Epoch 30/50
# 2/2 [==============================] - 4s 857ms/step - loss: 1.0565e-06 - accuracy: 1.0000 - val_loss: 0.4855 - val_accuracy: 0.8571
# Epoch 31/50
# 2/2 [==============================] - 3s 845ms/step - loss: 5.3593e-05 - accuracy: 1.0000 - val_loss: 0.4653 - val_accuracy: 0.8571
# Epoch 32/50
# 2/2 [==============================] - 3s 806ms/step - loss: 3.3842e-07 - accuracy: 1.0000 - val_loss: 0.4510 - val_accuracy: 0.8571
# Epoch 33/50
# 2/2 [==============================] - 3s 881ms/step - loss: 6.3280e-07 - accuracy: 1.0000 - val_loss: 0.4377 - val_accuracy: 0.8571
# Epoch 34/50
# 2/2 [==============================] - 3s 831ms/step - loss: 3.4953e-06 - accuracy: 1.0000 - val_loss: 0.4201 - val_accuracy: 0.8571
# Epoch 35/50
# 2/2 [==============================] - 3s 828ms/step - loss: 5.6376e-07 - accuracy: 1.0000 - val_loss: 0.3965 - val_accuracy: 0.8571
# Epoch 36/50
# 2/2 [==============================] - 3s 893ms/step - loss: 4.1881e-06 - accuracy: 1.0000 - val_loss: 0.3762 - val_accuracy: 0.8571
# Epoch 37/50
# 2/2 [==============================] - 3s 811ms/step - loss: 6.1326e-04 - accuracy: 1.0000 - val_loss: 0.3590 - val_accuracy: 0.8571
# Epoch 38/50
# 2/2 [==============================] - 3s 830ms/step - loss: 1.5344e-06 - accuracy: 1.0000 - val_loss: 0.3538 - val_accuracy: 0.8571
# Epoch 39/50
# 2/2 [==============================] - 3s 851ms/step - loss: 1.0072e-06 - accuracy: 1.0000 - val_loss: 0.3409 - val_accuracy: 0.8571
# Epoch 40/50
# 2/2 [==============================] - 3s 839ms/step - loss: 6.2884e-07 - accuracy: 1.0000 - val_loss: 0.3316 - val_accuracy: 0.8571
# Epoch 41/50
# 2/2 [==============================] - 3s 831ms/step - loss: 0.0105 - accuracy: 1.0000 - val_loss: 0.2215 - val_accuracy: 0.9524
# Epoch 42/50
# 2/2 [==============================] - 3s 846ms/step - loss: 2.9006e-05 - accuracy: 1.0000 - val_loss: 0.1088 - val_accuracy: 0.9524
# Epoch 43/50
# 2/2 [==============================] - 3s 934ms/step - loss: 2.2779e-06 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9524
# Epoch 44/50
# 2/2 [==============================] - 3s 893ms/step - loss: 1.2384e-06 - accuracy: 1.0000 - val_loss: 0.0339 - val_accuracy: 1.0000
# Epoch 45/50
# 2/2 [==============================] - 3s 875ms/step - loss: 3.1305e-06 - accuracy: 1.0000 - val_loss: 0.0359 - val_accuracy: 1.0000
# Epoch 46/50
# 2/2 [==============================] - 3s 880ms/step - loss: 6.6672e-06 - accuracy: 1.0000 - val_loss: 0.0504 - val_accuracy: 1.0000
# Epoch 47/50
# 2/2 [==============================] - 3s 1s/step - loss: 1.1896e-05 - accuracy: 1.0000 - val_loss: 0.0699 - val_accuracy: 0.9524
# Epoch 48/50
# 2/2 [==============================] - 5s 1s/step - loss: 1.5522e-05 - accuracy: 1.0000 - val_loss: 0.0921 - val_accuracy: 0.9048
# Epoch 49/50
# 2/2 [==============================] - 5s 1s/step - loss: 5.9866e-05 - accuracy: 1.0000 - val_loss: 0.1147 - val_accuracy: 0.9048
# Epoch 50/50
# 2/2 [==============================] - 4s 798ms/step - loss: 8.2340e-06 - accuracy: 1.0000 - val_loss: 0.1367 - val_accuracy: 0.9048

# %%
plt.plot(range(0, EPOCHS) ,hist.history['loss'], label='Training Loss')
plt.plot(range(0, EPOCHS) ,hist.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Visualizing Loss Metric')
plt.legend()
plt.show()

# %%
plt.plot(range(0, EPOCHS) ,hist.history['accuracy'], label='Training Accuracy')
plt.plot(range(0, EPOCHS) ,hist.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Visualizing Accuracy Metric')
plt.legend()
plt.show()

# %%
model.evaluate(X_test, y_test)
# Out:
# 2/2 [==============================] - 0s 107ms/step - loss: 0.0710 - accuracy: 0.9778
# [0.07102163136005402, 0.9777777791023254]

# %%
def predict(path):
    img = tf.keras.preprocessing.image.load_img(path)
    img = tf.keras.preprocessing.image.smart_resize(tf.keras.preprocessing.image.img_to_array(img)/255.0,(IMG_SHAPE,IMG_SHAPE))
    pred = model.predict(np.array([img]))[0]
    plt.imshow(img)
    if (pred >= 0.6):
        plt.title('Overloaded Truck')
    elif (pred > 0.4) and (pred < 0.6):
        plt.title("Not Sure")
    else:
        plt.title("Truck Not Overoaded")
    plt.show()

# %%
predict('data\OT _NT\OT & NT/11-OT.jpg')
